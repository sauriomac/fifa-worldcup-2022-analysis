# %% [markdown]
# # 02 - Limpieza de Datos
# Objetivo: tratar nulos, estandarizar tipos y preparar dataset procesado.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/fifa_world_cup_2022.csv')
df_clean = df.copy()
df_clean = df_clean.drop_duplicates()
df_clean.to_csv('../data/processed/fifa_world_cup_2022_clean.csv', index=False)
