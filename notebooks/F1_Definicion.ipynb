# %% [markdown]
# # Proyecto FIFA World Cup 2022
# ## Fase 1: Definición del problema y entorno reproducible
#
# **Asignatura:** MCDI500 – Herramientas de Software Científico
#
# **Integrantes:**
# - Enzo Pinilla
# - Claudio Alarcón
# - Luis Espinoza
#
# **Docente:** Dr. Omar Salinas Silva
#
# **Objetivo de la Fase 1:** establecer la base técnica y metodológica del proyecto mediante la definición del problema, la configuración del entorno reproducible y la validación inicial del conjunto de datos.

# %% [markdown]
# # Problemática
#
# La Copa Mundial FIFA Qatar 2022 generó una gran cantidad de información estadística relacionada con el desempeño de las selecciones participantes. Sin embargo, la existencia de múltiples indicadores deportivos dificulta determinar cuáles de estas variables presentan una mayor influencia sobre la obtención de victorias durante el torneo.
#
# Variables como la posesión de balón, la cantidad de pases, los intentos al arco, las faltas o las tarjetas disciplinarias podrían influir en el resultado de un partido, pero su impacto no resulta evidente sin un análisis sistemático de los datos.
#
# Para abordar esta problemática es necesario disponer de un entorno de trabajo reproducible que permita organizar adecuadamente los datos, documentar las decisiones metodológicas, registrar los cambios realizados y garantizar que los resultados puedan ser replicados y verificados por cualquier integrante del equipo.

# %% [markdown]
# # Pregunta orientadora
#
# ¿Qué estadísticas de juego influyen en la victoria de una selección durante la Copa Mundial FIFA Qatar 2022?

# %% [markdown]
# # Objetivo general
#
# Desarrollar un entorno reproducible para analizar las estadísticas de juego del Mundial FIFA Qatar 2022 e identificar variables asociadas a la victoria de una selección mediante herramientas de ciencia de datos, documentación técnica y control de versiones colaborativo.

# %% [markdown]
# # Objetivos específicos
#
# 1. Organizar una estructura de repositorio que permita separar datos originales, datos procesados, notebooks, documentación, resultados y código reutilizable.
#
# 2. Configurar un entorno reproducible mediante Python, Jupyter Notebook y un archivo requirements.txt.
#
# 3. Explorar y documentar las características principales del dataset FIFA World Cup 2022.
#
# 4. Implementar control de versiones mediante Git y GitHub utilizando ramas y commits descriptivos.
#
# 5. Vincular la documentación técnica, los notebooks y el repositorio con el flujo de trabajo definido para el proyecto.

# %% [markdown]
# # Dataset utilizado
#
# Para el desarrollo del proyecto se utilizará el conjunto de datos:
#
# **FIFA World Cup 2022 Complete Dataset**
#
# Fuente: https://www.kaggle.com/datasets/die9origephit/fifa-world-cup-2022-complete-dataset
#
# El dataset contiene información detallada de los partidos disputados durante la Copa Mundial FIFA Qatar 2022.
#
# Entre las variables disponibles se encuentran:
#
# - Goles
# - Asistencias
# - Posesión de balón
# - Pases completados
# - Intentos al arco
# - Tarjetas amarillas
# - Tarjetas rojas
# - Faltas
# - Offsides
# - Resultado final
#
# Estas variables permiten realizar análisis descriptivos para identificar posibles relaciones entre el rendimiento estadístico de una selección y la obtención de victorias.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# # Función de carga de datos
#
# Para favorecer la reutilización del código y mantener una estructura reproducible, la lectura del dataset se implementa mediante una función.

# %%
def cargar_datos(ruta):
    """
    Carga el dataset FIFA World Cup 2022 desde la ruta especificada.

    Parameters
    ----------
    ruta : str
        Ruta del archivo CSV.

    Returns
    -------
    pandas.DataFrame
        DataFrame con los datos cargados.
    """
    ruta = Path(ruta)
    rutas_posibles = [
        ruta,
        Path.cwd() / ruta,
        Path.cwd().parent / ruta,
        Path.cwd() / "data" / "raw" / "Fifa_world_cup_matches.csv",
        Path.cwd().parent / "data" / "raw" / "Fifa_world_cup_matches.csv",
    ]

    for ruta_posible in rutas_posibles:
        if ruta_posible.exists():
            return pd.read_csv(ruta_posible)

    raise FileNotFoundError(
        "No se encontro el CSV. Usa data/raw/Fifa_world_cup_matches.csv "
        "o verifica el directorio desde donde se ejecuta el notebook."
    )

# %% [markdown]
# # Carga inicial del dataset
#
# La siguiente celda realiza la lectura del archivo CSV almacenado en la carpeta data/raw.

# %%
df = cargar_datos("../data/raw/Fifa_world_cup_matches.csv")

# %% [markdown]
# # Validación de estructura
#
# A continuación se verifica la cantidad de registros y variables disponibles en el dataset.

# %%
print("Dimensiones del dataset:")
print(df.shape)
# Out:
# Dimensiones del dataset:
# (64, 88)

# %% [markdown]
# # Vista preliminar de los datos
#
# Se muestran las primeras filas para comprender la estructura del conjunto de datos y validar que la carga fue exitosa.

# %%
df.head()
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#           date     hour category  ...  penalties scored team1  \
# 0  20 NOV 2022  17 : 00  Group A  ...                       0
# ...

# %% [markdown]
# # Información general del dataset
#
# La siguiente celda permite inspeccionar tipos de datos y posibles valores faltantes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %% [markdown]
# # Estadísticas descriptivas iniciales
#
# Se generan métricas descriptivas básicas para obtener una primera comprensión del contenido del dataset.

# %%
df.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %% [markdown]
# # Interpretación inicial
#
# La carga del dataset fue realizada correctamente y se verificó la disponibilidad de las variables necesarias para el análisis.
#
# La inspección inicial permite conocer la cantidad de registros, la estructura de las columnas y los tipos de datos presentes en el conjunto de información.
#
# Esta revisión preliminar constituye el punto de partida para las actividades de exploración y limpieza que serán desarrolladas en las siguientes fases del proyecto.

# %% [markdown]
# # Conclusiones de la Fase 1
#
# Durante esta primera fase se definió la problemática del proyecto, se establecieron los objetivos generales y específicos, se configuró la estructura inicial del repositorio y se validó la carga del dataset FIFA World Cup 2022.
#
# Asimismo, se verificó el correcto funcionamiento del entorno reproducible basado en Python, Jupyter Notebook y GitHub, permitiendo garantizar que los análisis posteriores puedan ejecutarse de forma consistente y trazable.
#
# Las siguientes etapas del proyecto estarán orientadas a la exploración de datos, la limpieza y transformación del dataset, el análisis descriptivo de las variables y la identificación de patrones asociados a la victoria de las selecciones participantes.
