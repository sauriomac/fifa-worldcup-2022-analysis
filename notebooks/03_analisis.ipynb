# %% [markdown]
# # 03 - Analisis
# Objetivo: construir metricas y visualizaciones principales del proyecto.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/processed/fifa_world_cup_2022_clean.csv')
df.describe(include='all')
