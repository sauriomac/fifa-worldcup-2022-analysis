# %% [markdown]
# # 01 - Analisis Exploratorio de Datos (EDA)
# Objetivo: explorar estructura, nulos y distribuciones iniciales.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta = '../data/raw/fifa_world_cup_2022.csv'
df = pd.read_csv(ruta)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ruta = '../data/raw/fifa_world_cup_2022.csv'
# ----> 2 df = pd.read_csv(ruta)
#       3 df.head()
#
# NameError: name 'pd' is not defined
